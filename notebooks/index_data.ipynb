# %% [markdown]
# ## Import libraries

# %%
import os
import json

from elasticsearch import AsyncElasticsearch

# %% [markdown]
# ## Indexing data

# %% [markdown]
# **Initialize client**

# %%
client = AsyncElasticsearch(
    hosts=os.getenv("ELASTICSEARCH_HOST"),
    api_key=os.getenv("ELASTICSEARCH_API_KEY")
)

# %% [markdown]
# **Load data**

# %%
with open("../data/mm_image.json", "r", encoding="utf-8") as f:
    data = json.load(f)
    
# transformed_data = []
# for item in data:
#     for product in item["products"]:
#         transformed_data.append(
#             {
#                 **product,
#                 "category": item["categories"]
#             }
#         )

# %%
import json
import re
from typing import Dict, Any, List, Union

def extract_combo_info(text: str) -> Dict[str, Any]:
    """
    Extract combo information from text string.
    Returns dict with combo details and calculated discount.
    """
    if not isinstance(text, str):
        return {"is_combo": False, "combo_text": None, "combo_price": None, "discount_percent": 0}
    
    # Pattern to match combo pricing like "Combo 2 giá 435000D" or "Combo 3 giá 500000D"
    combo_pattern = r'combo\s+(\d+)\s+giá\s+([\d,]+)d?'
    match = re.search(combo_pattern, text.lower())
    
    if match:
        combo_quantity = int(match.group(1))
        combo_price = int(match.group(2).replace(',', ''))
        
        return {
            "is_combo": True,
            "combo_text": text,
            "combo_quantity": combo_quantity,
            "combo_price": combo_price,
            "discount_percent": 0  # Will be calculated based on original price
        }
    
    # Try to extract percentage discount like "20%" or "15% off"
    percent_pattern = r'(\d+(?:\.\d+)?)%'
    percent_match = re.search(percent_pattern, text)
    
    if percent_match:
        discount_percent = float(percent_match.group(1))
        return {
            "is_combo": False,
            "combo_text": None,
            "combo_price": None,
            "discount_percent": discount_percent
        }
    
    return {"is_combo": False, "combo_text": None, "combo_price": None, "discount_percent": 0}

def calculate_discount_percent(original_price: float, final_price: float) -> float:
    """Calculate discount percentage from original and final prices."""
    if original_price <= 0:
        return 0
    return round(((original_price - final_price) / original_price) * 100, 2)

def fix_product_data(product: Dict[str, Any]) -> Dict[str, Any]:
    """
    Fix product data by properly handling discount and combo information.
    """
    fixed_product = product.copy()
    
    # Extract combo/discount info from the discount field
    discount_field = product.get("discount", "")
    combo_info = extract_combo_info(discount_field)
    
    original_price = product.get("original_price", 0)
    
    if combo_info["is_combo"]:
        # Handle combo products
        combo_quantity = combo_info["combo_quantity"]
        combo_price = combo_info["combo_price"]
        
        # Calculate per-unit price in combo
        per_unit_combo_price = combo_price / combo_quantity if combo_quantity > 0 else combo_price
        
        # Calculate discount percentage
        if original_price > 0:
            discount_percent = calculate_discount_percent(original_price, per_unit_combo_price)
        else:
            discount_percent = 0
        
        # Update fields
        fixed_product["discount"] = discount_percent
        fixed_product["final_price"] = per_unit_combo_price
        fixed_product["product_combo"] = combo_info["combo_text"]
        
        print(f"Fixed combo product: {combo_quantity} items for {combo_price}D")
        print(f"Per unit: {original_price}D -> {per_unit_combo_price}D ({discount_percent}% off)")
        
    else:
        # Handle regular discount
        discount_percent = combo_info["discount_percent"]
        
        if discount_percent > 0:
            # Calculate final price from discount percentage
            final_price = original_price * (1 - discount_percent / 100)
            fixed_product["discount"] = discount_percent
            fixed_product["final_price"] = round(final_price, 2)
            fixed_product["product_combo"] = None
            
            print(f"Fixed discount product: {original_price}D -> {final_price}D ({discount_percent}% off)")
        else:
            # No valid discount found, check if final_price suggests a discount
            current_final_price = product.get("final_price", original_price)
            
            if current_final_price != original_price and original_price > 0:
                # Calculate discount from existing prices
                calculated_discount = calculate_discount_percent(original_price, current_final_price)
                fixed_product["discount"] = calculated_discount
                fixed_product["product_combo"] = None
                
                print(f"Calculated discount: {original_price}D -> {current_final_price}D ({calculated_discount}% off)")
            else:
                # No discount
                fixed_product["discount"] = 0
                fixed_product["final_price"] = original_price
                fixed_product["product_combo"] = None
                
                print("No discount applied")
    
    return fixed_product

def validate_fixed_data(original: Dict[str, Any], fixed: Dict[str, Any]) -> bool:
    """
    Validate that the fixed data makes sense.
    """
    issues = []
    
    # Check discount field type
    if not isinstance(fixed["discount"], (int, float)):
        issues.append(f"Discount should be numeric, got: {type(fixed['discount'])}")
    
    # Check final price is reasonable
    original_price = fixed.get("original_price", 0)
    final_price = fixed.get("final_price", 0)
    
    if final_price > original_price:
        issues.append(f"Final price ({final_price}) is higher than original price ({original_price})")
    
    if final_price <= 0:
        issues.append(f"Final price should be positive, got: {final_price}")
    
    # Check discount percentage is reasonable
    discount = fixed.get("discount", 0)
    if discount < 0 or discount > 100:
        issues.append(f"Discount percentage should be 0-100, got: {discount}")
    
    if issues:
        print("Validation issues:")
        for issue in issues:
            print(f"  - {issue}")
        return False
    
    print("Validation passed!")
    return True

def process_products(products: List[Dict[str, Any]]) -> List[Dict[str, Any]]:
    """
    Process a list of products and fix their data.
    """
    fixed_products = []
    
    for i, product in enumerate(products):
        print(f"\n--- Processing Product {i+1} ---")
        print(f"Name: {product.get('product_name', 'N/A')}")
        print(f"Original discount field: {product.get('discount', 'N/A')}")
        
        try:
            fixed_product = fix_product_data(product)
            fixed_product["related_products"] = None
            if validate_fixed_data(product, fixed_product):
                fixed_products.append(fixed_product)
                print("✅ Product fixed successfully")
            else:
                print("❌ Product validation failed")
                fixed_products.append(product)  # Keep original if fix failed
                
        except Exception as e:
            print(f"❌ Error processing product: {e}")
            fixed_products.append(product)  # Keep original if error occurred
    
    return fixed_products

# %%
processed_data = process_products(data)
# Out:
# --- Processing Product 1 ---
# Name: Khổ qua dồn thịt
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 2 ---
# Name: Khoai mỡ thịt xay, 650-850g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 3 ---
# Name: Đùi gà tươi tháo khớp khay CP
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4 ---
# Name: Đùi tỏi gà công nghiệp CP VN, 1kg
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 5 ---
# Name: Đuôi heo đông lạnh nhập khẩu
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 6 ---
# Name: Đùi tỏi gà MM, 1kg
# Original discount field: 9
# Calculated discount: 93900D -> 85000D (9.48% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 7 ---
# Name: Đùi tỏi gà công nghiệp LBC
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 8 ---
# Name: Dựng heo loại 1
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 9 ---
# Name: Xương đuôi heo
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 10 ---
# Name: Nạc heo xay
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 11 ---
# Name: Thăn phi lê heo loại 1
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 12 ---
# Name: Nạc heo xay
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 13 ---
# Name: Tim heo
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 14 ---
# Name: Vành tai heo
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 15 ---
# Name: Mỡ vụn heo loại 2
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 16 ---
# Name: Heo sữa đông lạnh 3.0-3.5kg
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 17 ---
# Name: Mỡ lưng heo loại 1
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 18 ---
# Name: Dồi trường
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 19 ---
# Name: Bao tử heo
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 20 ---
# Name: Lưỡi heo
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 21 ---
# Name: Cật heo - bầu dục
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 22 ---
# Name: Thịt heo rừng, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 23 ---
# Name: Nạc đùi heo đông lạnh nhập khẩu
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 24 ---
# Name: Gan heo
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 25 ---
# Name: Sườn non heo đông lạnh
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 26 ---
# Name: Cốt lết heo đông lạnh nhập khẩu
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 27 ---
# Name: Sườn non heo đông lạnh nhập khẩu
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 28 ---
# Name: Xương ống heo đông lạnh nhập khẩu
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 29 ---
# Name: Tã giấy Moony Nhật Bản M64
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 30 ---
# Name: Nạc vai heo đông lạnh nhập khẩu
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 31 ---
# Name: Nạc dăm heo đông lạnh nhập khẩu
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 32 ---
# Name: Dựng heo đông lạnh nhập khẩu
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 33 ---
# Name: Kem bánh cá vani đậu đỏ, hộp 3 cây, 150ml
# Original discount field: 17
# Calculated discount: 87000D -> 72000D (17.24% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 34 ---
# Name: Tã giấy Bobby Fresh siêu mỏng size M 76 miếng
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 35 ---
# Name: Kem bánh cá vani đậu đỏ, 150ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 36 ---
# Name: Kem bánh cá đậu đỏ/dâu /socola , hộp 3 cây, 150ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 37 ---
# Name: Kem Wall's Topten vani soco, hộp 5 cây, 57g/55g
# Original discount field: 8
# Calculated discount: 51000D -> 47100D (7.65% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 38 ---
# Name: Khoai môn Lệ Phố nhân hải sản, 260g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 39 ---
# Name: Kem Haagen Dazs strawberry pint, 473ml
# Original discount field: Combo 2 giá 435000D
# Fixed combo product: 2 items for 435000D
# Per unit: 259000D -> 217500.0D (16.02% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 40 ---
# Name: Khoai môn Lệ Phố Đông Đô, gói 260g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 41 ---
# Name: Chả giò xốp chay Cholimex, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 42 ---
# Name: Kem sữa chua Lottle việt quất, hộp 6 cây, 85ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 43 ---
# Name: Xoài cát vuông đông lạnh, 600g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 44 ---
# Name: Rau hỗn hợp đông lạnh MM (MEGA MARKET) 1kg *1 Gói
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 45 ---
# Name: Khoai môn cấp đông Agri, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 46 ---
# Name: Anh đào đông lạnh, hộp 550g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 47 ---
# Name: Khoai lang sợi ngọt Agri, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 48 ---
# Name: Bắp ngọt đông lạnh We Are Fresh, 1kg
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 49 ---
# Name: Rau hỗn hợp Agri (5 loại), 2kg
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 50 ---
# Name: Bắp non MM, gói 1kg
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 51 ---
# Name: Bắp Mỹ Ngọt cắt khoanh Agri, 1kg
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 52 ---
# Name: Bắp ngọt đông lạnh MM Pro, 2kg
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 53 ---
# Name: Đậu Hà Lan MM Pro, 1kg
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 54 ---
# Name: Đậu Hà Lan MM Pro, 2kg
# Original discount field: 5
# Calculated discount: 146000D -> 139000D (4.79% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 55 ---
# Name: Bắp Mỹ ngọt Agri Foods, 2kg
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 56 ---
# Name: Đậu Hà Lan Vsafe Food, 1kg
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 57 ---
# Name: Đậu Hà Lan Early Dawn, 2kg
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 58 ---
# Name: Kem dâu Vinamilk, 1 lít
# Original discount field: 18
# Calculated discount: 91000D -> 75000D (17.58% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 59 ---
# Name: Khoai tây Lutosa sợi lớn, 1kg
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 60 ---
# Name: Kem Haagen Dazs cooki & cream pint, 473ml
# Original discount field: None
# Calculated discount: 296000D -> 435000D (-46.96% off)
# Validation issues:
#   - Final price (435000) is higher than original price (296000)
#   - Discount percentage should be 0-100, got: -46.96
# ❌ Product validation failed
#
# --- Processing Product 61 ---
# Name: Khoai tây MC Cain Golden Long, 750g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 62 ---
# Name: Kem Cornetto mini soco/vani, hộp 12 cây, 18g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 63 ---
# Name: Kem hộp Nestle Oreo, 240g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 64 ---
# Name: Kem khoai môm Vinamilk, 1 lít
# Original discount field: 20
# Calculated discount: 94000D -> 75000D (20.21% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 65 ---
# Name: Kem sầu riêng Vinamilk, 1 lít
# Original discount field: 20
# Calculated discount: 94000D -> 75000D (20.21% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 66 ---
# Name: Kem Vinamilk dừa, 870ml/1 lít
# Original discount field: 20
# Calculated discount: 94000D -> 75000D (20.21% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 67 ---
# Name: Kem đậu xanh Vinamilk, 1 lít
# Original discount field: 20
# Calculated discount: 94000D -> 75000D (20.21% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 68 ---
# Name: Kem hộp đậu xanh sữa dừa Kido, 900ml
# Original discount field: 24
# Calculated discount: 78000D -> 59000D (24.36% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 69 ---
# Name: Kem hộp sầu riêng sữa dừa, 900ml
# Original discount field: 24
# Calculated discount: 78000D -> 59000D (24.36% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 70 ---
# Name: Kem hộp Merino dâu vani, 900ml
# Original discount field: 24
# Calculated discount: 78000D -> 59000D (24.36% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 71 ---
# Name: Kem Celano soco & vani hương socola, 800ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 72 ---
# Name: Kem dừa socola vani Vinamilk, 1 lít
# Original discount field: 16
# Calculated discount: 94000D -> 79000D (15.96% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 73 ---
# Name: Trứng vịt muối lòng đỏ Biên Hòa, thùng 100 quả
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 74 ---
# Name: Bánh ít trần Cholimex, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 75 ---
# Name: Chạo tôm Cholimex,350g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 76 ---
# Name: Kem Selection Double Dutch, 450g
# Original discount field: 22
# Calculated discount: 126000D -> 98100D (22.14% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 77 ---
# Name: Trứng vịt muối lòng đỏ Ba Huân, 50 quả
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 78 ---
# Name: Nem lụi Vissan, 300g
# Original discount field: 10
# Calculated discount: 69000D -> 62000D (10.14% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 79 ---
# Name: Bánh xếp Mandu thịt Bibigo, 350g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 80 ---
# Name: Bò viên Big Meal, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 81 ---
# Name: Bánh cuốn hải sản GN, 250g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 82 ---
# Name: Giò sống MM, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 83 ---
# Name: Nem chua rán Đông Đô, 420g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 84 ---
# Name: Bánh xếp tôm thịt Bamboo GN, gói 10 cái, 50g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 85 ---
# Name: Cá thu chay Phạm Gia Phát, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 86 ---
# Name: Nem nướng Vissan đặc biệt, 1kg
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 87 ---
# Name: Bò viên Vissan, 200g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 88 ---
# Name: Sữa dâu Binggrae, lốc 6 hộp, 200ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 89 ---
# Name: Chả lụa chay Phạm Gia Phát, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 90 ---
# Name: Sữa tiệt trùng TH TRUE MILK MILK SOCOLA 110ML*4
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 91 ---
# Name: Chả cá chay Phạm Gia Phát, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 92 ---
# Name: Sữa tiệt trùng TH hương dâu, lốc 4 hộp, 110ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 93 ---
# Name: Sữa đậu nành Fami Vinasoy nguyên chất, 1 lít
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 94 ---
# Name: Sữa đậu nành LACTASOY Nhập khẩu Thái Lan 1L
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 95 ---
# Name: Sữa chuối BINGGRAE 200ML*6
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 96 ---
# Name: Sữa hạt óc chó TH True Nut, lốc 4 hộp, 180ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 97 ---
# Name: Sữa hạt macca TH True Milk Nut, lôc 4 hộp, 180ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 98 ---
# Name: Sữa đậu nành Fami Canxi ít đường, lốc 6 hộp, 200ml
# Original discount field: 10
# Calculated discount: 29000D -> 26000D (10.34% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 99 ---
# Name: Sữa chua Betagen lên men hương cam, lốc 4 hộp, 140ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 100 ---
# Name: Sữa đậu nành LACTASOY Socola Nhập khẩu Thái Lan 500ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 101 ---
# Name: Sữa đậu nành Fami Vinasoy canxi, 1 lít
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 102 ---
# Name: Sữa đậu nành Fami canxi ít đường, lốc 10 bịch, 200ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 103 ---
# Name: Sữa chua Betagen lên men hương cam, lốc 4 hộp, 85ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 104 ---
# Name: Sữa chua uống TH True Yogurt vị cam, lốc 4 hộp, 180ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 105 ---
# Name: Sữa chua uống Yomost bạc hà việt quất, lốc 4 chai, 170ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 106 ---
# Name: Sữa chua uống TH True Yogurt vị dâu, lốc 4 hộp, 180ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 107 ---
# Name: Sữa chua uống tiệt trùng Top Kid dâu, lốc 4 hộp, 110ml/hộp
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 108 ---
# Name: Sữa chua uống Top Kid dâu chuối lúa mạch, lốc 4 hộp, 110ml/hộp
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 109 ---
# Name: Sữa đậu đen óc chó hạnh nhân Sahmyook Foods, 950ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 110 ---
# Name: Sữa đậu đen óc chó hạnh nhân Sahmyook Foods, lốc 3 hộp, 190ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 111 ---
# Name: Sữa chua uống TH việt quất, lốc 4 hộp, 180ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 112 ---
# Name: Sữa đậu đen óc chó hạnh nhân Sahmyook Foods, 195ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 113 ---
# Name: Bò viên CP, 500g
# Original discount field: 19
# Calculated discount: 68000D -> 55000D (19.12% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 114 ---
# Name: Sữa hạt hạnh nhân TH True Nut, lốc 4 hộp, 180ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 115 ---
# Name: Sữa tiệt trùng Dalat Milk có đường, lốc 4 hộp, 180ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 116 ---
# Name: Sữa tiệt trùng Dalat Milk ít đường, lốc 4 hộp, 180ml/hộp
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 117 ---
# Name: Sữa đậu đen óc chó hạnh nhân Sahmyook Foods, lốc 3 hộp, 140ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 118 ---
# Name: Sữa tiệt trùng Vinamilk 100% ít đường, 1 lít
# Original discount field: 9
# Calculated discount: 37000D -> 33500D (9.46% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 119 ---
# Name: Sữa tiệt trùng Vinamilk 100% có đường, 1 lít
# Original discount field: 9
# Calculated discount: 37000D -> 33500D (9.46% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 120 ---
# Name: Sữa tiệt trùng Cô Gái Hà Lan cao khỏe có đường, lốc 4 hộp, 170ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 121 ---
# Name: Sữa tươi tiệt trùng TH True Milk có đường, lốc 8 gói, 220ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 122 ---
# Name: Sữa tiệt trùng Cô Gái Hà Lan có đường, lốc 4 hộp, 110ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 123 ---
# Name: Sữa tiệt trùng TH ít đường, lốc 4 hộp, 110ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 124 ---
# Name: Sữa tiệt trùng TH có đường, lốc 4 hộp, 110ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 125 ---
# Name: Sữa tươi tiệt trùng TH True Milk có đường, 1 lít
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 126 ---
# Name: Sữa tiệt trùng Cô Gái Hà Lan có đường, 965ml
# Original discount field: 7
# Calculated discount: 34000D -> 31500D (7.35% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 127 ---
# Name: Sữa tươi tiệt trùng TH True Milk ít đường, 1 lít
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 128 ---
# Name: Sữa tiệt trùng Meadow Fresh không béo, 1 lít
# Original discount field: 16
# Calculated discount: 51000D -> 43000D (15.69% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 129 ---
# Name: Sữa dinh dưỡng Flex Vinamilk không đường, 1 lít
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 130 ---
# Name: Sữa tiệt trùng Meadow Fresh ít béo, lốc 3 hộp, 200ml
# Original discount field: 11
# Calculated discount: 46000D -> 41000D (10.87% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 131 ---
# Name: Sữa tiệt trùng Promess ít béo, lốc 3 hộp, 200ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 132 ---
# Name: Sữa tiệt trùng Meadow Fresh ít béo, 1 lít
# Original discount field: 13
# Calculated discount: 49500D -> 43000D (13.13% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 133 ---
# Name: Sữa tươi tiệt trùng TH True Milk Topkid vị kem vanilla, lốc 4 hộp, 180ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 134 ---
# Name: Sữa tiệt trùng Dalat Milk vị tự nhiên, lốc 4 hộp, 180ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 135 ---
# Name: Sữa tiệt trùng Vinamilk 100% không đường, 1 lít
# Original discount field: 9
# Calculated discount: 36700D -> 33500D (8.72% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 136 ---
# Name: Sữa tươi tiệt trùng TH True Milk nguyên chất, 1 lít
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 137 ---
# Name: Sữa tươi tiệt trùng Cô Gái Hà Lan không đường, 965ml
# Original discount field: 7
# Calculated discount: 34000D -> 31500D (7.35% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 138 ---
# Name: Sữa đậu nành Ichiban đậu đỏ đậu xanh, 800ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 139 ---
# Name: Sữa đậu nành Ichiban hương đậu đỏ và đậu xanh, 350ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 140 ---
# Name: Sữa đậu nành Ichiban nguyên chất ít đường, 800ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 141 ---
# Name: Sữa chua uống Vinamilk Probi Gold mật ong và curcumin từ nghệ, lốc 4 chai, 130ml
# Original discount field: 7
# Calculated discount: 37500D -> 35000D (6.67% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 142 ---
# Name: Sữa thanh trùng Dalat Milk hương socola, 180ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 143 ---
# Name: Sữa chua uống Vinamilk Probi việt quất, lốc 4 chai, 130ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 144 ---
# Name: Sữa chua Betagen lên men hỗn hợp, lốc 6 hộp, 85ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 145 ---
# Name: Sữa chua uống PROBI D.GANG 65ML*5
# Original discount field: 9
# Calculated discount: 23600D -> 21500D (8.9% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 146 ---
# Name: Sữa chua Betagen lên men hương dứa, 300ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 147 ---
# Name: Sữa chua uống Vinamilk Probi hương dứa, lốc 5 chai, 65ml
# Original discount field: 12
# Calculated discount: 24400D -> 21500D (11.89% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 148 ---
# Name: Kem xịt Anchor, 400g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 149 ---
# Name: Sữa chua Betagen lên men dứa, lốc 4 hộp, 85ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 150 ---
# Name: Kem xịt Tatua socola, 250g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 151 ---
# Name: Sữa chua Betagen lên men không béo, lốc 4 hộp, 85ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 152 ---
# Name: Kem xịt Tatua, 250g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 153 ---
# Name: Phô mai kem hủ Pauly, lốc 6 hộp, 28g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 154 ---
# Name: Phô mai kem Bottega Zelachi, 200g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 155 ---
# Name: Kem chua Tatua, 1kg
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 156 ---
# Name: Kem xịt Paysan Breton, 250ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 157 ---
# Name: Phô mai lát TOAST 200G
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 158 ---
# Name: Phô mai lát BURGER 200G
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 159 ---
# Name: Phô mai ZELACHI MOZZA bào 200G
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 160 ---
# Name: Phô mai lát màu Dairymont, 1kg
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 161 ---
# Name: Phô mai lát SANDWICH 200G
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 162 ---
# Name: Phô mai Mozzarella Zelachi, 200g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 163 ---
# Name: Phô mai Vinamilk, 120g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 164 ---
# Name: Phô mai Prestige Brie, 125g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 165 ---
# Name: Phô mai Prestige Camembert, 125g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 166 ---
# Name: Phô mai kem Dairymont, 2kg
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 167 ---
# Name: Phô mai bột Fromagio, 1kg
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 168 ---
# Name: Phô mai lát Con bò cười TOAST 200G
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 169 ---
# Name: Phô mai lát Con Bò Cười Burger, 200g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 170 ---
# Name: Phô mai Imperial, 6 lát, 125g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 171 ---
# Name: Phô mai lát Con Bò Cười Original, 200g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 172 ---
# Name: Phô mai Tatua Mascapone, 1kg
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 173 ---
# Name: Phô mai Zelachi Fromagio bột, 100g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 174 ---
# Name: Phô mai Belcubes Plain, 78g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 175 ---
# Name: Phô mai Saputo Mozzarella cân kí
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 176 ---
# Name: Phô mai Con Bò Cười VQR Light, hộp 8 miếng, 200g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 177 ---
# Name: Phô mai Belcubes Plain, 125g
# Original discount field: Combo 2 giá 119,000
# Fixed combo product: 2 items for 119000D
# Per unit: 68000D -> 59500.0D (12.5% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 178 ---
# Name: Phô mai Zelachi Emmental, 100g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 179 ---
# Name: Phô mai lát Anchor Cheddar, 200g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 180 ---
# Name: Phô mai Zelachi Gouda, 200g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 181 ---
# Name: Phô mai Cheddar Bottega Zelachi, 2kg
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 182 ---
# Name: Phô mai Gouda, 100g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 183 ---
# Name: Phô mai lát vị sữa Chesdale Cheddar, 250g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 184 ---
# Name: Phô mai bào Bottega Zelachi Mozza, 1kg
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 185 ---
# Name: Phô mai Emmental Even cân ký
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 186 ---
# Name: Phô mai Edam Holland cân ký
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 187 ---
# Name: Phô mai Zelachi Edam, 100g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 188 ---
# Name: Bơ lạt Bottega Zelachi, 250g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 189 ---
# Name: Phô mai lát Anchor Cheddar, 1040g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 190 ---
# Name: Bơ thực vật Baker Puff
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 191 ---
# Name: Phô mai Zelachi Cheddar, 100g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 192 ---
# Name: Bơ cục President mặn, 200g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 193 ---
# Name: Bơ lạt President, hộp 250g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 194 ---
# Name: Bơ cục President lạt, 125g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 195 ---
# Name: Bơ cục President lạt, 200g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 196 ---
# Name: Bơ cục President mặn, 125g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 197 ---
# Name: Sữa tiệt trùng Meadow Fresh canxi, lốc 3 hộp, 200ml
# Original discount field: -12
# Calculated discount: 52000D -> 46000D (11.54% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 198 ---
# Name: Bơ thực vật Palffy cân ký
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 199 ---
# Name: Sữa Anlene đậm đặc vani, lốc 4 hộp, 125ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 200 ---
# Name: Bơ lạt tự nhiên TH True Butter, 5kg
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 201 ---
# Name: Sữa tiệt trùng Meadow Fresh canxi, 1 lít
# Original discount field: 14
# Calculated discount: 58000D -> 50000D (13.79% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 202 ---
# Name: Kim chi cải thảo chay cắt lát Gfu, 3kg
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 203 ---
# Name: Kim chi cải thảo cắt lát cay vừa GFU, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 204 ---
# Name: SỮA TIỆT TRÙNG NGUYÊN KEM HARVEY FRESH 1L
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 205 ---
# Name: Kim chi cải thảo cắt lát, 3kg
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 206 ---
# Name: Cải thảo chay GFU cắt lắt, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 207 ---
# Name: Kim chi cải thảo Bibigo, 1kg
# Original discount field: 19
# Calculated discount: 93000D -> 75000D (19.35% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 208 ---
# Name: Xúc xích DNA, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 209 ---
# Name: Kim chi cải thảo cay cao cấp GFU, 3kg
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 210 ---
# Name: Kim chi cải thảo Bibigo, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 211 ---
# Name: Kim chi cải thảo cắt lát Ông Kim's Bibigo, 3kg
# Original discount field: 11
# Calculated discount: 196000D -> 175000D (10.71% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 212 ---
# Name: Lạp xưởng tươi heo Homi, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 213 ---
# Name: Lạp xưởng tươi bò Homi, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 214 ---
# Name: Xúc xích hồ lô DNA, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 215 ---
# Name: Lạp xưởng tỏi CHENLIN 500G
# Original discount field: 14
# Calculated discount: 180000D -> 155000D (13.89% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 216 ---
# Name: Lạp xưởng tươi CHENLIN 500G
# Original discount field: 15
# Calculated discount: 183000D -> 155000D (15.3% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 217 ---
# Name: Xíu mại tôm Bamboo GN, 300g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 218 ---
# Name: Lạp xưởng tươi tôm Homi, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 219 ---
# Name: Sủi cảo tôm thịt Cholimex, 300g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 220 ---
# Name: HÁ CẢO CTE MINI - GÓI 500G
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 221 ---
# Name: Xíu mại tôm Agrex Top V, 625g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 222 ---
# Name: Há cảo GN Food hoa hồng, 300g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 223 ---
# Name: Há cảo tôm GN Food , 270g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 224 ---
# Name: Há cảo GN Food sò điệp, 300g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 225 ---
# Name: HA CAO BIGMEAL TOM THIT 500GR
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 226 ---
# Name: Há cảo Baby Bamboo GN, 1kg
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 227 ---
# Name: Há cảo Hải Thanh juice ngọt, 300g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 228 ---
# Name: Há cảo tôm Jumbo Hai Thanh, 300g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 229 ---
# Name: Há cảo tôm Agrex Top V, 625g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 230 ---
# Name: Há cảo Hai Thanh tôm hẹ đặc biệt, 300g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 231 ---
# Name: Bánh xếp Mandu nhân hải sản Bibigo, 350g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 232 ---
# Name: Bánh xếp Mandu Bibigo nhân thịt và bắp, 350g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 233 ---
# Name: Bánh bao kim sa GN, 240g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 234 ---
# Name: Hoành thánh Cholimex, 300g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 235 ---
# Name: Hoành thánh tôm thịt TopV Agrex, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 236 ---
# Name: Hoành thánh tôm thịt Big Meal, 360g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 237 ---
# Name: Gà 99 Poultry xiên que, 8 xiên, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 238 ---
# Name: Gà Popcorn Poultry, 300g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 239 ---
# Name: Trứng vịt muối Ba Huân, hộp 10 quả
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 240 ---
# Name: Xúc xích Vealz CP, 10 cây, 500g
# Original discount field: 25
# Calculated discount: 87000D -> 65000D (25.29% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 241 ---
# Name: Gà 99 Poultry Chips 500g, 20-22 miếng
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 242 ---
# Name: Trứng bắc thảo Ba Huân, hộp 10 quả
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 243 ---
# Name: Trứng bắc thảo Ba Huân, hộp 4 quả
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 244 ---
# Name: Trứng vịt muối Ba Huân, hộp 4 quả
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 245 ---
# Name: Trứng vịt muối Vĩnh Thành Đạt hộp 4
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 246 ---
# Name: Trứng bách thảo Vĩnh Thành Đạt hộp 4 60-62G
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 247 ---
# Name: Trứng gà ác Vĩnh Thành Đạt, giỏ 10 quả
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 248 ---
# Name: Xúc xích beer Arabiki Shinshu, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 249 ---
# Name: Xúc xích Vườn Bia, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 250 ---
# Name: Trứng gà Omega 3 Ba Huân, hộp 6 quả
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 251 ---
# Name: Xúc xích Roma Đức Việt, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 252 ---
# Name: Xúc xích CP Frankfuter, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 253 ---
# Name: Xúc xích Đức xông khói Nippon, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 254 ---
# Name: Xúc xích Salami tiêu đỏ, 200g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 255 ---
# Name: Xúc xích Đức LG (50*10), 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 256 ---
# Name: Xúc xích Việt Mỹ Le Gourmet, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 257 ---
# Name: Xúc xích xông khói Đức Việt, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 258 ---
# Name: Xúc xích khô cắt lát, 250g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 259 ---
# Name: Xúc xích khô Hungary cắt lát, 250g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 260 ---
# Name: Xúc xích Sài gòn xông khói MM, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 261 ---
# Name: Xúc xích xông khói Trường Vinh, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 262 ---
# Name: Xúc xích Funny Vissan, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 263 ---
# Name: Xúc xích heo hồ lô CP, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 264 ---
# Name: Xúc xích Vissan Happy, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 265 ---
# Name: Xúc xích Trường Vinh Thụy Sĩ 500G
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 266 ---
# Name: Xúc xích Le Gourmet Deli Sumo, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 267 ---
# Name: Tã giấy Bobby Fresh siêu mỏng L68
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 268 ---
# Name: Xúc xích Deli Le Gourmet, 500g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 269 ---
# Name: Tã giấy Bobby Fresh siêu mỏng size XL, gói 62 miếng
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 270 ---
# Name: Tã dán người lớn Sunmate size M/L
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 271 ---
# Name: Tã Bobby Fresh siêu mỏng, size XXL, gói 56 miếng
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 272 ---
# Name: Tinh nghệ nếp vàng Honimore, 200g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 273 ---
# Name: Tã dán Sunmate người lớn size L/XL
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 274 ---
# Name: Topping dâu Golden Farm, hủ 630g
# Original discount field: None
# ...
#
# --- Processing Product 4652 ---
# Name: Nước lau bếp ga và tủ lạnh Sumo, 800ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4653 ---
# Name: Nước xả Downy làn gió mát, 3 lít
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4654 ---
# Name: Khăn ướt Yuniku, 20 tờ
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4655 ---
# Name: Nước súc miệng P/S Pro Complete kháng khuẩn bảo vệ, 500ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4656 ---
# Name: Nước lau sàn Sunlight lily & hương thảo, túi 3.6kg
# Original discount field: -1
# Calculated discount: 71000D -> 70000D (1.41% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4657 ---
# Name: Thuốc nhuộm L'Oreal màu 4 nâu tự nhiên
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4658 ---
# Name: Nước tẩy trang Pond's Micellar sạch dịu nhẹ sáng da, 235ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4659 ---
# Name: Khăn ướt cồn Letgreen, gói 90 miếng
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4660 ---
# Name: Lăn khử mùi khô thoáng Romano hương nước hoa gentleman, 50ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4661 ---
# Name: Sữa tắm Romano sát khuẩn Classic, 650g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4662 ---
# Name: Bàn chải đánh răng trẻ em Colgate Minions 2 cái
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4663 ---
# Name: Bông bọt biển tẩy tế bào chết Miraculous trắng cát
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4664 ---
# Name: Bông bọt biển tẩy tế bào chết Miraculous xanh cát
# Original discount field: 12
# Calculated discount: 41000D -> 36000D (12.2% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4665 ---
# Name: Tắm gội Coast Classic Scent, 946ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4666 ---
# Name: Thuốc nhuộm L'oreal 3 nâu tự nhiên
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4667 ---
# Name: Dao cạo Gillette Mach3 Plus + 2 lưỡi
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4668 ---
# Name: Đèn bàn led cảm ứng RD.20.V2Led
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4669 ---
# Name: Dao cạo Gillette Mach3 Turbo 2
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4670 ---
# Name: Lưỡi dao cạo Gillette Proglide, lốc 2 cái
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4671 ---
# Name: Lưỡi dao cạo râu Mach3, vỉ 3 cái
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4672 ---
# Name: Lưỡi dao Gillette Mach3+ 6 cái
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4673 ---
# Name: Đèn bàn bảo vệ thị lực RD RL 38 led
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4674 ---
# Name: Lăn khử mùi Refre Natural hương deluxe, 40ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4675 ---
# Name: Sữa rửa mặt Xmen Go Detox, tuýp 100g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4676 ---
# Name: Kem đánh bóng Cana, 100g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4677 ---
# Name: Dầu gội Dove ngăn gãy rụng tóc, 640g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4678 ---
# Name: Sữa rửa mặt Xmen Go Refresh, tuýp 100g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4679 ---
# Name: Rượu vang Rosso Organic, 75CL
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4680 ---
# Name: Rượu Whisky Goldking, 75CL
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4681 ---
# Name: Rượu vang Antawara Rosé, 75CL
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4682 ---
# Name: Xà bông cục Lifebuoy diệt khuẩn matcha khổ qua, 90g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4683 ---
# Name: Rượu Veritas Est Sauvifnon Blanc 75CL
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4684 ---
# Name: Rượu Jacob's Creek Char Cla, 75CL
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4685 ---
# Name: Rượu Veritas Est Cab Sau, 75CL
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4686 ---
# Name: Rượu Veritas Spec.E Cab Sau, 75CL
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4687 ---
# Name: Rượu Clos Du Chateau Bord, 75CL
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4688 ---
# Name: Đậu phộng-PINATTSUHAISANCAY95/85G
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4689 ---
# Name: Ngũ cốc Familia Jungle Crun, 250g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4690 ---
# Name: Bia Far East Ipa, thùng 12 lon, 330ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4691 ---
# Name: Bia 1664 Blanc, thùng 24 chai, 330ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4692 ---
# Name: Bia East West Pale Ale, thùng 12 lon, 330ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4693 ---
# Name: Đậu phộng- PINATTSU MUCCAY 95/85G
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4694 ---
# Name: Nước giải khát Coca Cola Zero, 600ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4695 ---
# Name: Ngũ cốc Familia soco chocolate Ted, 250g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4696 ---
# Name: Đậu phộng PINATTSU cốt dừa 95G
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4697 ---
# Name: Nước tăng lực Monster xoài, 355ml
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4698 ---
# Name: Bánh snack tôm Oishi vị cay đặc biệt, 80g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4699 ---
# Name: Bánh snack que Akiko nhân sữa, lốc 20 gói, 8g/gói
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4700 ---
# Name: Snack Pillows nhân vị socola, gói 100g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4701 ---
# Name: Bánh que Lucky socola, 45g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4702 ---
# Name: Bánh snack que Akiko nhân cà phê moka, lốc 20 gói, 8g/gói
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4703 ---
# Name: Bánh quy giòn MM hình dạng chữ cái, 320g
# Original discount field: -2
# Calculated discount: 56000D -> 55000D (1.79% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4704 ---
# Name: Snack Pillows nhân sữa dừa, gói 100g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4705 ---
# Name: Bánh quy giòn MM hình dạng hải sản, 320g
# Original discount field: 17
# Calculated discount: 66000D -> 55000D (16.67% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4706 ---
# Name: Bánh quy dừa MM nhân mứt thơm, 500g
# Original discount field: 25
# Calculated discount: 79000D -> 59000D (25.32% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4707 ---
# Name: Bánh quy MM nhân kem cà phê, 450g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4708 ---
# Name: Bánh quy giòn MM nhân mứt thơm, 500g
# Original discount field: 22
# Calculated discount: 76000D -> 59000D (22.37% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4709 ---
# Name: Bánh ly Yan Yan vị dâu, 50g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4710 ---
# Name: Bánh quy MM nhân kem, 450g
# Original discount field: 11
# Calculated discount: 66000D -> 59000D (10.61% off)
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4711 ---
# Name: Gum Xylitol Blueberry, lốc 6 hũ, 137.8g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4712 ---
# Name: Kẹo gum không đường Xylitol Blueberry, 6 hũ, 58g/hũ
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4713 ---
# Name: Kẹo gum Xylitol mát lạnh, 6 hũ, 137.8/130.5g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4714 ---
# Name: Gum Xylitol Limemint, lốc 6 hũ, 137.8g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4715 ---
# Name: Gum Xylitol dâu, lốc 6 hũ, 58g/hũ
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4716 ---
# Name: Kẹo gum Xylitol lime mint, lốc 12 hũ, 26.1g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4717 ---
# Name: Mì xào Nissin gà cay phô mai Hàn Quốc, lốc 5 gói, 72g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4718 ---
# Name: Bánh tráng Tây Ninh Doxaco 22cm, 200g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4719 ---
# Name: Mì tôm chua Wai Wai, lốc 5 gói, 60g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4720 ---
# Name: Bột cốt dừa Taky, 50g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4721 ---
# Name: Mì WaiWai thịt heo bằm, lốc 5 gói, 60g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4722 ---
# Name: Kẹo gum Xylitol limemint, vỉ 55 viên, 2.9g/viên
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4723 ---
# Name: Mì chay WaiWai, lốc 5 gói, 60g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4724 ---
# Name: Mì Sate TH, lốc 5 gói, gói giấy 70g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4725 ---
# Name: Mì WaiWai vịt tiềm, lốc 5 gói, 60g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4726 ---
# Name: Mì chay chua WaiWai, lốc 5 gói, 60g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4727 ---
# Name: Mì ớt thập cẩm Wai Wai, lốc 5 gói, 60g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4728 ---
# Name: Củ giềng (riềng) Lâm Đồng, 100g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4729 ---
# Name: Củ gừng Lâm Đồng, 100g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4730 ---
# Name: Tỏi tép thơm Hải Dương, 100g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4731 ---
# Name: Củ nghệ Lâm Đồng, 100g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4732 ---
# Name: Tỏi Hải Dương, 100g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4733 ---
# Name: Sả cây Tiền Giang, 100g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4734 ---
# Name: Chuối cau Bến Tre chín ươm
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4735 ---
# Name: Táo Dazzle, xuất xứ New Zealand
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4736 ---
# Name: Táo Gala size nhỏ, xuất xứ Mỹ
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4737 ---
# Name: Nấm đùi gà baby xuất xứ Hàn Quốc, gói 300g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4738 ---
# Name: Má đùi khay LBC
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4739 ---
# Name: Bông thiên lý Bình Phước, 200g
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4740 ---
# Name: Dưa Huỳnh Long
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4741 ---
# Name: Cà rốt nhập khẩu, xuất xứ Trung Quốc
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully
#
# --- Processing Product 4742 ---
# Name: Giấy gói có bóng khí 3m*30cm
# Original discount field: None
# No discount applied
# Validation passed!
# ✅ Product fixed successfully

# %%
import asyncio
from asyncio import Semaphore

async def delete_index(client, index_name):
    await client.indices.delete(index=index_name, ignore=[400, 404])

async def index_products(client, data):
    await delete_index(client, "product-data-v2")
    semaphore = Semaphore(32)
    tasks = [
        index_with_semaphore(client, product, semaphore)
        for product in data
    ]
    await asyncio.gather(*tasks)

async def index_with_semaphore(client, product, semaphore):
    async with semaphore:
        await client.index(
            index="product-data-v2",
            id=product["product_id"],
            document=product
        )

await index_products(client, processed_data)
# Out:
# /var/folders/xl/lwf29p0n1bs99ksdkvmkq_n80000gn/T/ipykernel_76212/1710155432.py:5: DeprecationWarning: Passing transport options in the API method is deprecated. Use 'Elasticsearch.options()' instead.
#   await client.indices.delete(index=index_name, ignore=[400, 404])
